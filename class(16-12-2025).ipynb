# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("laptop_data.csv")

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df["OpSys"].unique()
# Out:
# array(['macOS', 'No OS', 'Windows 10', 'Mac OS X', 'Linux', 'Android',
#        'Windows 10 S', 'Chrome OS', 'Windows 7'], dtype=object)

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def covert_os(x):
    if "Windows" in x:
        return "Windows"
    elif "mac" or "Mac" in x:
        return "mac"
    else:
        return "Other"

# %%
df["os_cat"]=df["OpSys"].apply(covert_os)

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.drop(columns=["OpSys"],inplace=True)

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df1=pd.read_csv("quikr_car.csv")

# %%
df1
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df1.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# np.int64(94)

# %%
df1
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df1["name"]
# Out:
# 0        Hyundai Santro Xing XO eRLX Euro III
# 1                     Mahindra Jeep CL550 MDI
# 2                  Maruti Suzuki Alto 800 Vxi
# 3      Hyundai Grand i10 Magna 1.2 Kappa VTVT
# 4            Ford EcoSport Titanium 1.5L TDCi
#                         ...
# 887                                        Ta
# 888                       Tata Zest XM Diesel
# 889                        Mahindra Quanto C8
# 890                  Honda Amaze 1.2 E i VTEC
# 891                 Chevrolet Sail 1.2 LT ABS
# Name: name, Length: 892, dtype: object

# %%
def convert_name(x):
    words=x.split()
    last_three=words[-3:]
    return " ".join(last_three)

# %%
lst=[3,4,5,6,7,8]

# %%
x=lst[-1:-4:-1]

# %%
x.reverse()

# %%
x
# Out:
# [6, 7, 8]

# %%
df1["new_name"]=df1["name"].apply(convert_name)

# %%
df1
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type            new_name
# ...

# %%
df1.drop(columns=["name"],inplace=True)

# %%
df1
# Out:
#        company  year          Price  kms_driven fuel_type            new_name
# 0      Hyundai  2007         80,000  45,000 kms    Petrol       eRLX Euro III
# 1     Mahindra  2006       4,25,000      40 kms    Diesel      Jeep CL550 MDI
# 2       Maruti  2018  Ask For Price  22,000 kms    Petrol        Alto 800 Vxi
# 3      Hyundai  2014       3,25,000  28,000 kms    Petrol      1.2 Kappa VTVT
# 4         Ford  2014       5,75,000  36,000 kms    Diesel  Titanium 1.5L TDCi
# ..         ...   ...            ...         ...       ...                 ...
# 887       Tara  zest       3,10,000         NaN       NaN                  Ta
# 888       Tata  2018       2,60,000  27,000 kms    Diesel      Zest XM Diesel
# 889   Mahindra  2013       3,90,000  40,000 kms    Diesel  Mahindra Quanto C8
# 890      Honda  2014       1,80,000      Petrol       NaN            E i VTEC
# 891  Chevrolet  2014       1,60,000      Petrol       NaN          1.2 LT ABS
#
# [892 rows x 6 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   company     892 non-null    object
#  1   year        892 non-null    object
#  2   Price       892 non-null    object
#  3   kms_driven  840 non-null    object
#  4   fuel_type   837 non-null    object
#  5   new_name    892 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
df1["year"].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
df1=df1[df1["year"].str.isdigit()]

# %%
df1
# Out:
#        company  year          Price    kms_driven fuel_type  \
# 0      Hyundai  2007         80,000    45,000 kms    Petrol
# 1     Mahindra  2006       4,25,000        40 kms    Diesel
# 2       Maruti  2018  Ask For Price    22,000 kms    Petrol
# 3      Hyundai  2014       3,25,000    28,000 kms    Petrol
# 4         Ford  2014       5,75,000    36,000 kms    Diesel
# ..         ...   ...            ...           ...       ...
# 886     Toyota  2009       3,00,000  1,32,000 kms    Petrol
# 888       Tata  2018       2,60,000    27,000 kms    Diesel
# 889   Mahindra  2013       3,90,000    40,000 kms    Diesel
# 890      Honda  2014       1,80,000        Petrol       NaN
# 891  Chevrolet  2014       1,60,000        Petrol       NaN
#
#                  new_name
# 0           eRLX Euro III
# 1          Jeep CL550 MDI
# 2            Alto 800 Vxi
# 3          1.2 Kappa VTVT
# 4      Titanium 1.5L TDCi
# ..                    ...
# 886  Toyota Corolla Altis
# ...

# %%
df1["year"].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '2003', '2004', '1995', '2002', '2001'], dtype=object)

# %%
df1["year"]=df1["year"].astype("int")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6920\3457493237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["year"]=df1["year"].astype("int")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   company     842 non-null    object
#  1   year        842 non-null    int64
#  2   Price       842 non-null    object
#  3   kms_driven  840 non-null    object
#  4   fuel_type   837 non-null    object
#  5   new_name    842 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 46.0+ KB

# %%
df1
# Out:
#        company  year          Price    kms_driven fuel_type  \
# 0      Hyundai  2007         80,000    45,000 kms    Petrol
# 1     Mahindra  2006       4,25,000        40 kms    Diesel
# 2       Maruti  2018  Ask For Price    22,000 kms    Petrol
# 3      Hyundai  2014       3,25,000    28,000 kms    Petrol
# 4         Ford  2014       5,75,000    36,000 kms    Diesel
# ..         ...   ...            ...           ...       ...
# 886     Toyota  2009       3,00,000  1,32,000 kms    Petrol
# 888       Tata  2018       2,60,000    27,000 kms    Diesel
# 889   Mahindra  2013       3,90,000    40,000 kms    Diesel
# 890      Honda  2014       1,80,000        Petrol       NaN
# 891  Chevrolet  2014       1,60,000        Petrol       NaN
#
#                  new_name
# 0           eRLX Euro III
# 1          Jeep CL550 MDI
# 2            Alto 800 Vxi
# 3          1.2 Kappa VTVT
# 4      Titanium 1.5L TDCi
# ..                    ...
# 886  Toyota Corolla Altis
# ...

# %%
df1["Price"].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
df1=df1[df1["Price"]!='Ask For Price']

# %%
df1["Price"].unique()
# Out:
# array(['80,000', '4,25,000', '3,25,000', '5,75,000', '1,75,000',
#        '1,90,000', '8,30,000', '2,50,000', '1,82,000', '3,15,000',
#        '4,15,000', '3,20,000', '10,00,000', '5,00,000', '3,50,000',
#        '1,60,000', '3,10,000', '75,000', '1,00,000', '2,90,000', '95,000',
#        '1,80,000', '3,85,000', '1,05,000', '6,50,000', '6,89,999',
#        '4,48,000', '5,49,000', '5,01,000', '4,89,999', '2,80,000',
#        '3,49,999', '2,84,999', '3,45,000', '4,99,999', '2,35,000',
#        '2,49,999', '14,75,000', '3,95,000', '2,20,000', '1,70,000',
#        '85,000', '2,00,000', '5,70,000', '1,10,000', '4,48,999',
#        '18,91,111', '1,59,500', '3,44,999', '4,49,999', '8,65,000',
#        '6,99,000', '3,75,000', '2,24,999', '12,00,000', '1,95,000',
#        '3,51,000', '2,40,000', '90,000', '1,55,000', '6,00,000',
#        '1,89,500', '2,10,000', '3,90,000', '1,35,000', '16,00,000',
#        '7,01,000', '2,65,000', '5,25,000', '3,72,000', '6,35,000',
# ...

# %%
df1["Price"]=df1["Price"].str.replace(",","")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6920\4037066618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Price"]=df1["Price"].str.replace(",","")

# %%
df1["Price"].unique()
# Out:
# array(['80000', '425000', '325000', '575000', '175000', '190000',
#        '830000', '250000', '182000', '315000', '415000', '320000',
#        '1000000', '500000', '350000', '160000', '310000', '75000',
#        '100000', '290000', '95000', '180000', '385000', '105000',
#        '650000', '689999', '448000', '549000', '501000', '489999',
#        '280000', '349999', '284999', '345000', '499999', '235000',
#        '249999', '1475000', '395000', '220000', '170000', '85000',
#        '200000', '570000', '110000', '448999', '1891111', '159500',
#        '344999', '449999', '865000', '699000', '375000', '224999',
#        '1200000', '195000', '351000', '240000', '90000', '155000',
#        '600000', '189500', '210000', '390000', '135000', '1600000',
#        '701000', '265000', '525000', '372000', '635000', '550000',
#        '485000', '329500', '251111', '569999', '69999', '299999',
#        '399999', '450000', '270000', '158400', '179000', '125000',
# ...

# %%
df1["Price"]=df1["Price"].astype("int")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6920\1769142007.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Price"]=df1["Price"].astype("int")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   company     819 non-null    object
#  1   year        819 non-null    int64
#  2   Price       819 non-null    int64
#  3   kms_driven  819 non-null    object
#  4   fuel_type   816 non-null    object
#  5   new_name    819 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.8+ KB

# %%
df1["kms_driven"].unique()
# Out:
# array(['45,000 kms', '40 kms', '28,000 kms', '36,000 kms', '41,000 kms',
#        '25,000 kms', '24,530 kms', '60,000 kms', '30,000 kms',
#        '32,000 kms', '48,660 kms', '4,000 kms', '16,934 kms',
#        '43,000 kms', '35,550 kms', '39,522 kms', '39,000 kms',
#        '55,000 kms', '72,000 kms', '15,975 kms', '70,000 kms',
#        '23,452 kms', '35,522 kms', '48,508 kms', '15,487 kms',
#        '82,000 kms', '20,000 kms', '68,000 kms', '38,000 kms',
#        '27,000 kms', '33,000 kms', '46,000 kms', '16,000 kms',
#        '47,000 kms', '35,000 kms', '30,874 kms', '15,000 kms',
#        '29,685 kms', '1,30,000 kms', '19,000 kms', '54,000 kms',
#        '13,000 kms', '38,200 kms', '22,000 kms', '50,000 kms',
#        '13,500 kms', '3,600 kms', '45,863 kms', '60,500 kms',
#        '12,500 kms', '18,000 kms', '13,349 kms', '29,000 kms',
#        '44,000 kms', '42,000 kms', '14,000 kms', '49,000 kms',
#        '36,200 kms', '51,000 kms', '1,04,000 kms', '33,333 kms',
# ...

# %%
df1=df1[df1["kms_driven"]!='Petrol']

# %%
df1["kms_driven"].unique()
# Out:
# array(['45,000 kms', '40 kms', '28,000 kms', '36,000 kms', '41,000 kms',
#        '25,000 kms', '24,530 kms', '60,000 kms', '30,000 kms',
#        '32,000 kms', '48,660 kms', '4,000 kms', '16,934 kms',
#        '43,000 kms', '35,550 kms', '39,522 kms', '39,000 kms',
#        '55,000 kms', '72,000 kms', '15,975 kms', '70,000 kms',
#        '23,452 kms', '35,522 kms', '48,508 kms', '15,487 kms',
#        '82,000 kms', '20,000 kms', '68,000 kms', '38,000 kms',
#        '27,000 kms', '33,000 kms', '46,000 kms', '16,000 kms',
#        '47,000 kms', '35,000 kms', '30,874 kms', '15,000 kms',
#        '29,685 kms', '1,30,000 kms', '19,000 kms', '54,000 kms',
#        '13,000 kms', '38,200 kms', '22,000 kms', '50,000 kms',
#        '13,500 kms', '3,600 kms', '45,863 kms', '60,500 kms',
#        '12,500 kms', '18,000 kms', '13,349 kms', '29,000 kms',
#        '44,000 kms', '42,000 kms', '14,000 kms', '49,000 kms',
#        '36,200 kms', '51,000 kms', '1,04,000 kms', '33,333 kms',
# ...

# %%
df1["kms_driven"]=df1["kms_driven"].str.replace(" kms","")

# %%
df1["kms_driven"].unique()
# Out:
# array(['45,000', '40', '28,000', '36,000', '41,000', '25,000', '24,530',
#        '60,000', '30,000', '32,000', '48,660', '4,000', '16,934',
#        '43,000', '35,550', '39,522', '39,000', '55,000', '72,000',
#        '15,975', '70,000', '23,452', '35,522', '48,508', '15,487',
#        '82,000', '20,000', '68,000', '38,000', '27,000', '33,000',
#        '46,000', '16,000', '47,000', '35,000', '30,874', '15,000',
#        '29,685', '1,30,000', '19,000', '54,000', '13,000', '38,200',
#        '22,000', '50,000', '13,500', '3,600', '45,863', '60,500',
#        '12,500', '18,000', '13,349', '29,000', '44,000', '42,000',
#        '14,000', '49,000', '36,200', '51,000', '1,04,000', '33,333',
#        '33,600', '5,600', '7,500', '26,000', '24,330', '65,480',
#        '2,00,000', '59,000', '99,000', '2,800', '21,000', '11,000',
#        '66,000', '3,000', '7,000', '38,500', '37,200', '43,200', '24,800',
#        '45,872', '40,000', '11,400', '97,200', '52,000', '31,000',
# ...

# %%
df1["kms_driven"]=df1["kms_driven"].str.replace(",","")

# %%
df1["kms_driven"].unique()
# Out:
# array(['45000', '40', '28000', '36000', '41000', '25000', '24530',
#        '60000', '30000', '32000', '48660', '4000', '16934', '43000',
#        '35550', '39522', '39000', '55000', '72000', '15975', '70000',
#        '23452', '35522', '48508', '15487', '82000', '20000', '68000',
#        '38000', '27000', '33000', '46000', '16000', '47000', '35000',
#        '30874', '15000', '29685', '130000', '19000', '54000', '13000',
#        '38200', '22000', '50000', '13500', '3600', '45863', '60500',
#        '12500', '18000', '13349', '29000', '44000', '42000', '14000',
#        '49000', '36200', '51000', '104000', '33333', '33600', '5600',
#        '7500', '26000', '24330', '65480', '200000', '59000', '99000',
#        '2800', '21000', '11000', '66000', '3000', '7000', '38500',
#        '37200', '43200', '24800', '45872', '40000', '11400', '97200',
#        '52000', '31000', '175430', '37000', '65000', '3350', '75000',
# ...

# %%
df1["kms_driven"]=df1["kms_driven"].astype("int")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   company     817 non-null    object
#  1   year        817 non-null    int64
#  2   Price       817 non-null    int64
#  3   kms_driven  817 non-null    int64
#  4   fuel_type   816 non-null    object
#  5   new_name    817 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 44.7+ KB

# %%
df1
# Out:
#       company  year   Price  kms_driven fuel_type              new_name
# 0     Hyundai  2007   80000       45000    Petrol         eRLX Euro III
# 1    Mahindra  2006  425000          40    Diesel        Jeep CL550 MDI
# 3     Hyundai  2014  325000       28000    Petrol        1.2 Kappa VTVT
# 4        Ford  2014  575000       36000    Diesel    Titanium 1.5L TDCi
# 6        Ford  2012  175000       41000    Diesel             Ford Figo
# ..        ...   ...     ...         ...       ...                   ...
# 883    Maruti  2011  270000       50000    Petrol          Ritz VXI ABS
# 885      Tata  2009  110000       30000    Diesel            DLE BS III
# 886    Toyota  2009  300000      132000    Petrol  Toyota Corolla Altis
# 888      Tata  2018  260000       27000    Diesel        Zest XM Diesel
# 889  Mahindra  2013  390000       40000    Diesel    Mahindra Quanto C8
#
# [817 rows x 6 columns]

# %%
df1.isnull().sum()
# Out:
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     1
# new_name      0
# dtype: int64

# %%
df1["fuel_type"].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
df1["fuel_type"].value_counts()
# Out:
# fuel_type
# Petrol    428
# Diesel    386
# LPG         2
# Name: count, dtype: int64

# %%
df1["fuel_type"]=df1["fuel_type"].fillna("Petrol")

# %%
df1["fuel_type"].unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %%
df1
# Out:
#       company  year   Price  kms_driven fuel_type              new_name
# 0     Hyundai  2007   80000       45000    Petrol         eRLX Euro III
# 1    Mahindra  2006  425000          40    Diesel        Jeep CL550 MDI
# 3     Hyundai  2014  325000       28000    Petrol        1.2 Kappa VTVT
# 4        Ford  2014  575000       36000    Diesel    Titanium 1.5L TDCi
# 6        Ford  2012  175000       41000    Diesel             Ford Figo
# ..        ...   ...     ...         ...       ...                   ...
# 883    Maruti  2011  270000       50000    Petrol          Ritz VXI ABS
# 885      Tata  2009  110000       30000    Diesel            DLE BS III
# 886    Toyota  2009  300000      132000    Petrol  Toyota Corolla Altis
# 888      Tata  2018  260000       27000    Diesel        Zest XM Diesel
# 889  Mahindra  2013  390000       40000    Diesel    Mahindra Quanto C8
#
# [817 rows x 6 columns]

# %%
df2=pd.read_csv("Bengaluru_House_Data.csv")

# %%
df2
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df2["area_type"]
# Out:
# 0        Super built-up  Area
# 1                  Plot  Area
# 2              Built-up  Area
# 3        Super built-up  Area
# 4        Super built-up  Area
#                  ...
# 13315          Built-up  Area
# 13316    Super built-up  Area
# 13317          Built-up  Area
# 13318    Super built-up  Area
# 13319    Super built-up  Area
# Name: area_type, Length: 13320, dtype: object

# %%
df2["area_type"]=df2["area_type"].str.rstrip()

# %%
df2
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df2["area_type"].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df2["area_type"]=df2["area_type"].str.replace(" ","")

# %%
df2
# Out:
#                area_type   availability                  location       size  \
# 0      Superbuilt-upArea         19-Dec  Electronic City Phase II      2 BHK
# 1               PlotArea  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2           Built-upArea  Ready To Move               Uttarahalli      3 BHK
# 3      Superbuilt-upArea  Ready To Move        Lingadheeranahalli      3 BHK
# 4      Superbuilt-upArea  Ready To Move                  Kothanur      2 BHK
# ...                  ...            ...                       ...        ...
# 13315       Built-upArea  Ready To Move                Whitefield  5 Bedroom
# 13316  Superbuilt-upArea  Ready To Move             Richards Town      4 BHK
# 13317       Built-upArea  Ready To Move     Raja Rajeshwari Nagar      2 BHK
# 13318  Superbuilt-upArea         18-Jun           Padmanabhanagar      4 BHK
# 13319  Superbuilt-upArea  Ready To Move              Doddathoguru      1 BHK
#
# ...

# %%
df2["availability"].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Feb', '18-Nov', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '20-Feb',
#        '18-Apr', '20-Aug', '18-Oct', '19-Mar', '17-Sep', '18-Dec',
#        '17-Aug', '19-Apr', '18-Jun', '22-Dec', '22-Jan', '18-Aug',
#        '19-Jan', '17-Jul', '18-Jul', '21-Jun', '20-May', '19-Aug',
#        '18-Sep', '17-May', '17-Jun', '21-May', '18-Jan', '20-Mar',
#        '17-Dec', '16-Mar', '19-Jun', '22-Jun', '19-Jul', '21-Feb',
#        'Immediate Possession', '19-May', '17-Nov', '20-Oct', '20-Jun',
#        '19-Feb', '21-Oct', '21-Jan', '17-Mar', '17-Apr', '22-May',
#        '19-Oct', '21-Jul', '21-Nov', '21-Mar', '16-Dec', '22-Mar',
#        '20-Jan', '21-Sep', '21-Aug', '14-Nov', '19-Nov', '15-Nov',
#        '16-Jul', '15-Jun', '17-Feb', '20-Nov', '20-Jul', '16-Sep',
#        '15-Oct', '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan',
#        '16-Nov', '20-Apr', '16-Jan', '14-Jul'], dtype=object)

# %%
df2["new_availability"]=df2["availability"].apply(lambda x:1 if x=="Ready To Move" else 0)

# %%
df2
# Out:
#                area_type   availability                  location       size  \
# 0      Superbuilt-upArea         19-Dec  Electronic City Phase II      2 BHK
# 1               PlotArea  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2           Built-upArea  Ready To Move               Uttarahalli      3 BHK
# 3      Superbuilt-upArea  Ready To Move        Lingadheeranahalli      3 BHK
# 4      Superbuilt-upArea  Ready To Move                  Kothanur      2 BHK
# ...                  ...            ...                       ...        ...
# 13315       Built-upArea  Ready To Move                Whitefield  5 Bedroom
# 13316  Superbuilt-upArea  Ready To Move             Richards Town      4 BHK
# 13317       Built-upArea  Ready To Move     Raja Rajeshwari Nagar      2 BHK
# 13318  Superbuilt-upArea         18-Jun           Padmanabhanagar      4 BHK
# 13319  Superbuilt-upArea  Ready To Move              Doddathoguru      1 BHK
#
# ...

# %%
df2.drop(columns=["availability"],inplace=True)

# %%
df2
# Out:
#                area_type                  location       size  society  \
# 0      Superbuilt-upArea  Electronic City Phase II      2 BHK  Coomee
# 1               PlotArea          Chikka Tirupathi  4 Bedroom  Theanmp
# 2           Built-upArea               Uttarahalli      3 BHK      NaN
# 3      Superbuilt-upArea        Lingadheeranahalli      3 BHK  Soiewre
# 4      Superbuilt-upArea                  Kothanur      2 BHK      NaN
# ...                  ...                       ...        ...      ...
# 13315       Built-upArea                Whitefield  5 Bedroom  ArsiaEx
# 13316  Superbuilt-upArea             Richards Town      4 BHK      NaN
# 13317       Built-upArea     Raja Rajeshwari Nagar      2 BHK  Mahla T
# 13318  Superbuilt-upArea           Padmanabhanagar      4 BHK  SollyCl
# 13319  Superbuilt-upArea              Doddathoguru      1 BHK      NaN
#
#       total_sqft  bath  balcony   price  new_availability
# 0           1056   2.0      1.0   39.07                 0
# ...

# %%
df2["location"].unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
def convert_location(x):
