# %%
import os

# %%
os.system("notepad")

# %%
os.system("Paint")

# %%
os.system("chrome")

# %%
os.remove("mayur.txt")

# %%
fd=open("mayur.txt","r")

# %%
os.rename("sample.txt","new_sample.txt")

# %%
f1=open("sample.txt","r")

# %%
f2=open("new_sample.txt","r")

# %%
print(f2.read())

# %%
import math

# %%
s=str(math.factorial(1000))

# %%
int(s[0:21])

# %%
math.pi

# %%
os.system("notepad")

# %%
import os as o
def openNotepad(s):
    if(s=="can you please open the notepad for me"):
        print("open notepad");
        o.system("notepad")
    else:
        print("wrong")
s="can you please open the notepad for me"
openNotepad(s)

# %%
inp=("please enter your prompt")
if "notepad" in inp:
    os.system("notepad")
elif "chrome" in inp:
    os.system("chrome")
else:
    print("wrong prompt")

# %%
import samplemodule

# %%
samplemodule.printing()

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
isinstance(lr,LogisticRegression)
