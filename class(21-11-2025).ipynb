# %%
print("hello")
# Out:
# hello

# %%
# !pip install requests

# %%
import requests

# %%
response=requests.get("https://github.com/pypi/warehouse/issues?q=is%3Aopen+is%3Aissue+label%3Adocumentation")

# %%
response.status_code
# Out:
# 200

# %%
string=response.text

# %%
string
# Out:
# '\n\n\n\n\n\n<!DOCTYPE html>\n<html\n  lang="en"\n  \n  data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"\n  data-a11y-animated-images="system" data-a11y-link-underlines="true"\n  \n  >\n\n\n\n\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  \n\n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-8e973f836952.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light_high_contrast-34b642d57214.css" /><link crossor
# ...

# %%
pattern="\w+\:\/\/\w+\.\w+\.\w+"

# %%
import re
print(re.findall(pattern,string))
# Out:
# ['https://github.githubassets.com', 'https://avatars.githubusercontent.com', 'https://github.githubassets.com', 'https://avatars.githubusercontent.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://github.githubassets.com', 'https://api.githubcopilot.com', 'https:
# ...

# %%
res1=requests.get("https://en.wikipedia.org/wiki/List_of_HTTP_status_codes")

# %%
res1.status_code
# Out:
# 403

# %%
print(re.sub("\w+\:\/\/\w+\.\w+\.\w+","",string))
# Out:
# <!DOCTYPE html>
# <html
#   lang="en"
#
#   data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"
#   data-a11y-animated-images="system" data-a11y-link-underlines="true"
#
#   >
#
#
#
#
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="">
#   <link rel="dns-prefetch" href="">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#   <link rel="preconnect" href="" crossorigin>
#   <link rel="preconnect" href="">
#
#
#
#
# ...

# %%
res2=requests.get("https://www.rottentomatoes.com/")

# %%
res2.status_code
# Out:
# 200

# %%
res2.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" dir="ltr" xmlns="http://www.w3.org/1999/xhtml" prefix="fb: http://www.facebook.com/2008/fbml og: http://opengraphprotocol.org/schema/">\n    <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">\n\n        \n            \n                <!-- OneTrust Cookies Consent Notice start for rottentomatoes.com --> <script src="https://cdn.cookielaw.org/consent/01978557-1604-76a7-ad7c-18216757cf52/otSDKStub.js"  type="text/javascript" charset="UTF-8" data-domain-script="01978557-1604-76a7-ad7c-18216757cf52" integrity="sha384-+pVk9UG5UhkNJidnAEsw69vj3H+me4n1jCJ2EOj3YTZvGBHgDu2h1HocvlMlqfEu" crossorigin="anonymous" ></script> <script type="text/javascript"> function OptanonWrapper() { } </script> <!-- OneTrust Cookies Consent Notice end for rottentomatoes.com --> <!-- OneTrust IAB US Privacy (USP) --> <script src="https://cdn.cookielaw.org/opt-out/otCCPAiab.js" id="privacyCookie" type="text/javascript" charset="UTF-8" c
# ...
