# %%
def fun()
   print("hello")
fun()
# Out:
#   Cell In[1], line 1
#     def fun()
#              ^
# SyntaxError: expected ':'

# %%
lst=<2,3,4,5,6>
# Out:
#   Cell In[2], line 1
#     lst=<2,3,4,5,6>
#         ^
# SyntaxError: invalid syntax

# %%
age=int(input("enter your age"))
if age<18:
    print("adult")
else:
    print("child")
# Out:
# enter your age 56
# child

# %%
a=10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a=10/0
#
# ZeroDivisionError: division by zero

# %%
lst=[2,3,4,5]

# %%
lst[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 lst[7]
#
# IndexError: list index out of range

# %%
import math

# %%
math.factorial(10000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\anaconda4\Lib\site-packages\IPython\core\formatters.py:770, in PlainTextFormatter.__call__(self, obj)
#     763 stream = StringIO()
#     764 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     765     self.max_width, self.newline,
#     766     max_seq_length=self.max_seq_length,
#     767     singleton_pprinters=self.singleton_printers,
#     768     type_pprinters=self.type_printers,
#     769     deferred_pprinters=self.deferred_printers)
# --> 770 printer.pretty(obj)
#     771 printer.flush()
#     772 return stream.getvalue()
#
# File ~\anaconda3\anaconda4\Lib\site-packages\IPython\lib\pretty.py:394, in RepresentationPrinter.pretty(self, obj)
#     391 for cls in _get_mro(obj_class):
#     392     if cls in self.type_pprinters:
#     393         # printer registered in self.type_pprinters
# --> 394         return self.type_pprinters[cls](obj, self, cycle)
#     395     else:
#     396         # deferred printer
#     397         printer = self._in_deferred_types(cls)
#
# File ~\anaconda3\anaconda4\Lib\site-packages\IPython\lib\pretty.py:794, in _repr_pprint(obj, p, cycle)
#     792 """A pprint that just redirects to the normal repr function."""
#     793 # Find newlines and replace them with p.break_()
# --> 794 output = repr(obj)
#     795 lines = output.splitlines()
#     796 with p.group():
#
# ValueError: Exceeds the limit (4300 digits) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit

# %%
def fact(n):
    return n*fact(n-1)
fact(5)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 def fact(n):
#       2     return n*fact(n-1)
# ----> 3 fact(5)
#
# Cell In[9], line 2, in fact(n)
#       1 def fact(n):
# ----> 2     return n*fact(n-1)
#
# Cell In[9], line 2, in fact(n)
#       1 def fact(n):
# ----> 2     return n*fact(n-1)
#
#     [... skipping similar frames: fact at line 2 (2974 times)]
#
# Cell In[9], line 2, in fact(n)
#       1 def fact(n):
# ----> 2     return n*fact(n-1)
#
# RecursionError: maximum recursion depth exceeded

# %%
import ctypes

# %%
ctypes.string_at(0)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ctypes.string_at(0)
#
# File ~\anaconda3\anaconda4\Lib\ctypes\__init__.py:538, in string_at(ptr, size)
#     534 def string_at(ptr, size=-1):
#     535     """string_at(ptr[, size]) -> string
#     536
#     537     Return the byte string at void *ptr."""
# --> 538     return _string_at(ptr, size)
#
# OSError: exception: access violation reading 0x0000000000000000

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
a=int(input("enter a"))
b=int(input("enter b"))
print(a/b)
# Out:
# enter a 5
# enter b 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 a=int(input("enter a"))
#       2 b=int(input("enter b"))
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
try:
    a=int(input("enter first number"))
    b=int(input("enter sceond number"))
    print(a/b)
except:
    print("we cannot divide by zero")
# Out:
# enter first number 4
# enter sceond number 2
# 2.0

# %%
try:
    lst=[2,3,4,5,6,7,8,9]
    print(lst[15])
except:
    print("cannot access out of range value")
# Out:
# cannot access out of range value

# %%
4+"mayur"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 4+"mayur"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    a=int(input("eneter any number"))
    b=int(input("eneter other number"))
    print(a+b)
except:
    print("give both value as integers")
# Out:
# eneter any number 4
# eneter other number mayur
# give both value as integers

# %%
try:
    print(10/0)
except:
    print("cannot divide")
    print(5/0)
# Out:
# cannot divide
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 try:
# ----> 2     print(10/0)
#       3 except:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[24], line 5
#       3 except:
#       4     print("cannot divide")
# ----> 5     print(5/0)
#
# ZeroDivisionError: division by zero

# %%
try:
    print(10/0)
    try:
        print(5/2)
    except:
        print("can do")
except:
    print("cannot divide by zero")
# Out:
# cannot divide by zero

# %%
try:
    print(10/2)
    try:
        print(5/0)
    except:
        print("can do")
except:
    print("cannot divide by zero")
# Out:
# 5.0
# can do

# %%
try:
    print(10/2)
    try:
        print(5/2)
        try:
            print(10/0)
        except:
            print("hi")
    except:
        print("hello")
except:
    ("bye")
# Out:
# 5.0
# 2.5
# hi

# %%
try:
    print(10/0)
except:
    print("hello")
finally:
    print("done")
# Out:
# hello
# done

# %%
try:
    print(10/5)
except:
    print("cannot do")
finally:
    print("bilkul hoga")
# Out:
# 2.0
# bilkul hoga
