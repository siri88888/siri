# %%
import re

# %%
string="This is python class"
pattern="python"
print(re.findall(pattern,string))
# Out:
# ['python']

# %%
pattern1="p....n"
print(re.findall(pattern1,string))
# Out:
# ['python']

# %%
pattern2="p...n"
print(re.findall(pattern2,string))
# Out:
# []

# %%
s1="abababababba"
pattern3="babba"
print(re.findall(pattern3,s1))
# Out:
# ['babba']

# %%
s2="aaaaaabb"
pattern4="a*"
print(re.findall(pattern4,s2))
# Out:
# ['aaaaaa', '', '', '']

# %%
s2="aaaaaabb"
pattern4="a+"
print(re.findall(pattern4,s2))
# Out:
# ['aaaaaa']

# %%
string="aaaabb"
pattern5="^b"
print(re.findall(pattern5,string))
# Out:
# []

# %%
#write a pattern whose length is 5 and starts with ba
pattern="^ba..."
string="babbbbbb"
print(re.findall(pattern,string))
# Out:
# ['babbb']

# %%
string5="aaaaaab"
pattern="aaaaaaaab$"
print(re.findall(pattern,string5))
# Out:
# []

# %%
#write a pattern whose length is 6 starts with a and ends with b
pattern="^a....b$"
string="abbbab"
print(re.findall(pattern,string))
# Out:
# ['abbbab']

# %%
string="this is python programming and Python is a simple lnaguage"
pattern="python|Python"
print(re.findall(pattern,string))
# Out:
# ['python', 'Python']

# %%
string="this is python programming and Python is a simple lnaguage"
pattern="^p|^P"
print(re.findall(pattern,string))
# Out:
# []

# %%
string="juleus ceaser died in 1942"
pattern="\d+"
print(re.findall(pattern,string))
# Out:
# ['1942']

# %%
string="the person born in 27 april 1947"
pattern="\d+"
print(re.findall(pattern,string))
# Out:
# ['27', '1947']

# %%
string="I have 12 oranges and 15 apples"
pattern="\d+"
print(re.findall(pattern,string))
# Out:
# ['12', '15']

# %%
string="baaababaa"
pattern="[ab]"
print(re.match(pattern,string))
# Out:
# <re.Match object; span=(0, 1), match='b'>

# %%
string[0:1]
# Out:
# 'b'

# %%
string="caaababaa"
pattern="[a-z]"
print(re.match(pattern,string))
# Out:
# <re.Match object; span=(0, 1), match='c'>

# %%
string="1234"
pattern="[a-z0-9]"
print(re.match(pattern,string))
# Out:
# <re.Match object; span=(0, 1), match='1'>

# %%
string="@"
pattern="@"
print(re.match(pattern,string))
# Out:
# <re.Match object; span=(0, 1), match='@'>

# %%
string="mayur@"
pattern="@"
print(re.findall(pattern,string))
# Out:
# ['@']

# %%
string="xyz@gmail.com"
pattern="[a-z]+\@[a-z]+\.[a-z]+"
print(re.findall(pattern,string))
# Out:
# ['xyz@gmail.com']

# %%
string="abc123@gmail.co.in"
pattern="[a-z0-9]+\@[a-z]+\.[a-z]+\.[a-z]+"
print(re.findall(pattern,string))
# Out:
# ['abc123@gmail.co.in']

# %%
string="hahahahahaha"
pattern="[ha]+"
print(re.findall(pattern,string))
# Out:
# ['hahahahahaha']

# %%
string="mayurkulkarni456@gmail.com"

# %%
pattern="([a-z])([a-z0-9]+)(\@)([a-z]+)(\.)([a-z]+)"
match=re.search(pattern,string)

# %%
match.group(1)
# Out:
# 'm'

# %%
match.group(2)
# Out:
# 'ayurkulkarni456'

# %%
match.group(3)
# Out:
# '@'

# %%
match.group(4)
# Out:
# 'gmail'

# %%
match.group(5)
# Out:
# '.'

# %%
match.group(6)
# Out:
# 'com'

# %%
res=match.group(1)+len(match.group(2))*"#"

# %%
res
# Out:
# 'm###############'

# %%
res+match.group(3)+match.group(4)+match.group(5)+match.group(6)
# Out:
# 'm###############@gmail.com'

# %%
string="8888-7777-6666"
pattern="(\d{2})(\d{2})(\-)(\d{4})(\-)(\d{2})(\d{2})"
match=re.search(pattern,string)

# %%
match.group(1)
# Out:
# '88'

# %%
match.group(2)
# Out:
# '88'

# %%
match.group(3)
# Out:
# '-'

# %%
match.group(4)
# Out:
# '7777'

# %%
match.group(5)
# Out:
# '-'

# %%
match.group(6)
# Out:
# '66'

# %%
match.group(7)
# Out:
# '66'

# %%
match.group(1)+len(match.group(2))*"#"+match.group(3)+len(match.group(4))*"#"+match.group(5)+len(match.group(1))*"#"+match.group(7)
# Out:
# '88##-####-##66'
