# %%
class sample:
    def __init__(self,a,b):#parameterized constructor
        self.a=a
        self.b=b
    def display(self):
        print(self.a,self.b)

# %%
obj1=sample(2,3)

# %%
obj1.display()
# Out:
# 2 3

# %%
obj2=sample(5,6)

# %%
obj2.display()
# Out:
# 5 6

# %%
class test:
    def __init__(self):#defualt constrctor
        print("constrctor invoked")

# %%
obj=test()
# Out:
# constrctor invoked

# %%
class test:
    print("hello")
# Out:
# hello

# %%
class tp:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def calculate(self):
        print(self.a*self.b)

# %%
obj=tp(4,5)

# %%
obj.a
# Out:
# 4

# %%
obj.b
# Out:
# 5

# %%
self.a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 self.a
#
# NameError: name 'self' is not defined

# %%
mayur=tp(100,200)

# %%
mayur.a
# Out:
# 100

# %%
class tp:
    def __init__(self,a,b):
        self.__a=a
        self.b=b
    def calculate(self):
        print(self.a*self.b)

# %%
obj1=tp(34,45)

# %%
obj1.a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 obj1.a
#
# AttributeError: 'tp' object has no attribute 'a'

# %%
obj1.__a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 obj1.__a
#
# AttributeError: 'tp' object has no attribute '__a'

# %%
obj1._tp__a
# Out:
# 34

# %%
obj1._tp__a	="dummy"

# %%
obj1._tp__a
# Out:
# 'dummy'

# %%
class base:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def display1(self):
        print(self.a*self.b)
class derived(base):
    def __init__(self,a,b):
        super().__init__(a,b)
    def display(self):
        super().display1()

# %%
obj=derived(3,4)

# %%
obj.display()
# Out:
# 12

# %%
class base1:
    def __init__(self):
        print("hello")
class dervived1(base1):
    def __init__(self):
        print("dervied class ocnstructor")

# %%
d=dervived1()
# Out:
# dervied class ocnstructor

# %%
d.__init__()
# Out:
# dervied class ocnstructor

# %%
class base:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def display1(self):
        print(self.a*self.b)
class derived(base):
    def __init__(self,a,b):
        super().__init__(a,b)

        super().display1()

# %%
obj2=derived(3,4)
# Out:
# 12

# %%
class student:
    def __init__(self,sid,sname):
        self.sid=sid
        self.sname=sname
    def display1(self):
        print("student ID:",self.sid)
        print("student name:",self.sname)
class graduate(student):
    def __init__(self,sid,sname,degree,percentage):
        super().__init__(sid,sname)
        self.degree=degree
        self.percentage=percentage
    def display2(self):
        super().display1()
        print("Degree:",self.degree)
        print("Percentage:",self.percentage)

# %%
g=graduate(101,"mayur","Btech",60)

# %%
g.display2()
# Out:
# student ID: 101
# student name: mayur
# Degree: Btech
# Percentage: 60

# %%
super().sid
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 super().sid
#
# RuntimeError: super(): no arguments
