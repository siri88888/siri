# %%
import numpy as np

# %%
arr1=np.array([-2,3,-34,56,78,-90,8,3,4,5,6])

# %%
arr1
# Out:
# array([ -2,   3, -34,  56,  78, -90,   8,   3,   4,   5,   6])

# %%
b=np.sort(arr1)

# %%
arr1
# Out:
# array([ -2,   3, -34,  56,  78, -90,   8,   3,   4,   5,   6])

# %%
b
# Out:
# array([-90, -34,  -2,   3,   3,   4,   5,   6,   8,  56,  78])

# %%
arr1.sort()

# %%
arr1
# Out:
# array([-90, -34,  -2,   3,   3,   4,   5,   6,   8,  56,  78])

# %%
arr2=np.array([ -2,   3, -34,  56,  78, -90,   8,   3,   4,   5,   6])

# %%
np.argsort(arr2)
# Out:
# array([ 5,  2,  0,  1,  7,  8,  9, 10,  6,  3,  4])
